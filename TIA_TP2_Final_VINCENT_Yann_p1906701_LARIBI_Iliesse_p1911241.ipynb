# %% [markdown]
# # Technique d'ia : Réseaux de Neurones
# **Vincent Yann p1906701
# Laribi Iliesse p1911241**

# %% [markdown]
# # 3. Etude "théorique" de cas simples

# %% [markdown]
# ## 3.1 Influence de n
# On notera l'entrée courante X et le vecteur de poids courant du neurone gagnant W*.
# - Dans le cas ou n = 0 quelle sera la prochaine valeur des poids du neurone gagnant ?
#
#
# > Dans le cas où n le taux d'apprentissage initial est de 0
# Les poids ne seront pas modifié ni pour le neurone gagnant ni pour les autres
# La valeur de ses poids sera donc sa valeur initiale.
#
#
# - Même question dans le cas ou n = 1.
#
#
# > Si n est à 1 les poids des neurones seront mis à jour a chaque fois avec une amplitude maximale.
# Le taux est donc trop élevé, il vaut mieux le garder entre 0.1 et 0.01.
# Le neurone gagnant ne prendra pas ses voisins en compte et se déplacera directement à sa position "final".
# L'algorithme ne prendra pas en compte la distance topologique entre les neurones.
#
#
# - Dans le cas ou n ∈ ]0; 1[ (paramétrisation "normale") ou se situera le nouveau poids par rapport a W* et X
# en fonction de n (formule mathematique simple ou explication géométrique) ?
#
#
#
# > Géométriquement : le taux d'apprentissage n correpond à l'avancement du poids du noeud gagnant par rapport à sa position finale (en fonction de X).
# Par exemple si n = 1 le neurone gagnant se mettra à la position finale directement.
# Si n = 0 il ne bougera pas.
# Si n = 0.5 il se mettra à mettre chemin entre sa position initiale et finale.   La meilleure méthode est de bouger progressivement les noeuds gagnants pour que les poids des autres noeuds puissent s'agrandir aussi progressivement pour changer la forme de la figure petit à petit sans la déplacer entièrement a chaque fois.
#
#
#
#
# - Que va-t-il se passer si n > 1 ?
#
#
#
# > Si n est supérieur à 1 géométriquement le noeud gagnant se déplacera au-delà de sa position "cible". L'algorithme n'aboutira à rien.

# %% [markdown]
# ## 3.2 Influence de σ
# - Si σ augmente, les neurones proches du neurone gagnant (dans la carte), vont-ils plus ou moins apprendre l’entrée courante ?
#
#
#
# > Mathematiquement : Lorsque σ augmente la valeur de l'exponentielle sera plus petite. Donc l'exponetielle negative sera plus petite egalement. Donc Wij augmentera.
# Donc plus σ augmente plus les poids des neurones envers le neurone gagnant sont pris en compte.
# Les neurones vont donc apprendre plus de l'entrée courante.
# Plus σ est haut plus les neurones seront organisé.
#
#
#
#
# - Si σ est plus grand, à convergence, l’auto-organisation obtenue sera-t-elle donc plus “resserrée” (i.e. une distance plus faible entre les poids des neurones proches) ou plus “lâche” ?
#
#
# > Elle sera plus resséré car mieux organisé (apprend plus de l'entrée courante).
#
#
# - Quelle mesure (formule mathématique qui sera à implémenter dans la section 4) pourrait quantifier ce phénomène et donc mesurer l’influence de σ sur le comportement de l’algorithme ?
#
# > La formule de la section 2 : Algortihme dans la partie apprentisage de l'algortihme dans le petit 4.
# Celle qui calcule ∆wji (mise a jour des poids de toutes ses connexions presente sur le sujet)

# %% [markdown]
# ## 3.3 Influence de la distribution d’entrée
#
#  Prenons le cas très simple d’une carte à 1 neurone qui reçoit deux entrées X1 et X2.
#
#  - Si X1 et X2 sont présentés autant de fois, vers quelle valeur convergera le vecteur du poids du neurone (en supposant un η faible - pour ne pas avoir à tenir compte de l’ordre de présentation des entrées - et suffisamment de présentations - pour négliger l’influence de l’initialisation des poids) ?
#
# > Le vecteur de poids de neurones convergera vers le milieu des entrées X1 et X2 car les entrées X1 et X2 sont présentées autant de fois.
# Le vecteur de poids du neurone se trouvera à égale distance de X1 et de X2. C'est-à-dire W*= (X1 + X2) /2
#
#  - Même question si X1 est présenté n fois plus que X2.
#
# > Si X1 est n fois plus présenté que X2, cela signifie que X1 est plus fréquemment présenté que X2 dans l'algorithme d'apprentissage de la carte
# de Kohonen.
# Cela veut aussi dire que le vecteur de poids du neurone sera plus proche de X1 que de X2. Avec W*= (n*X1 + X2) / n+1
#
# En déduire comment vont se répartir les neurones en fonction de la densité des données dans le cas (normal) d’une carte à plusieurs neurones recevant des données d’une base d’apprentissage. Pour rappel, la mesure de quantification vectorielle permet de mesurer ce phénomène.
#
#
# > Dans le cas où la densité des données est uniforme, chaque neurone aura le même nombre d'entrées associées. Ainsi, la mesure de quantification vectorielle, qui mesure la qualité de la représentation de l'espace d'entrée dans l'espace de sortie de la carte, sera similaire pour tous les neurones de la carte. La répartition des neurones dans l'espace de sortie sera homogène.
# Au contraire, si la répartition des données n'est pas uniforme dans l'espace d'entrée alors les neurones ne sera pas homogène dans l'espace de sortie. Ils seront plus concentrés dans les régions de l'espace d'entrée où la densité des données est plus élevée, et à l'inverse moins nombreuse dans les régions où la densité est plus faible. Parfois modifier l'uniformité des données permet d'avoir des resulalts plus proches de ce que l'on souhaite. En effet changer l'uniformité revient à orienter les neurones vers des zones spécifiques que l'on souhaite voir plus détaillé que le reste.

# %% [markdown]
# # 4. Etude pratique

# %% [markdown]
# ## 4.2 Implémentation
#
# Nous avons réalisé les implémentations demandées au niveau des TODO.

# %% [markdown]
# ## 4.3 Analyse de l’algorithme
#
# Pour réaliser l’étude pratique du comportement de l’algorithme, utilisez une démarche scientifique i.e. faites des hypothèses (en particulier en regard de votre étude théorique faite dans la section 3) et confrontez les aux résultats/données obtenus (qualitativement et quantitativement avec la mesure d’erreur de quantification vectorielle fourni et avec la mesure d’auto-organisation que vous avez proposé à la section 3.2). En particulier, vous étudierez l’influence des éléments suivants sur le fonctionnement de l’algorithme de Kohonen :
#
# Les données de bases que l'on a pris:
# ETA = 0.05
# sigma = 5
# N = 30000
# Nafficahe = 10
# nsample = 1200
#
# - taux d’apprentissage η
#
# > Pour η = 0, les neurones sont à leur position initale. Ce qui correspond à ce que l'on a dit dans la partie 3, les neurones n'ont pas eu d'apprentissage donc ils ne bougent pas.
# ![image.png](data:image/png;base64,...)
# Pour η = 1, les neurones gagnants se déplacent tous à leur position finale. Chaque neurone apprend « trop ». Lorsqu’un neurone change de position ils changent la position de ses voisins avec lui. On peut dire que quand un neurone se déplace trop d’un coup il déplace toute la structure et ne lui laisse pas le temps de stabiliser. L'algorithme ne se terminera jamais.
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# Pour η = 1.1 nous observons le même résultat.
# Pour η=10, les neurones se déplacent plus loin que ce qu’il devrait (comme prédit dans la partie 3). Cela donne donc un comportement étrange qui n’aboutit à rien.
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
# - largeur du voisinage σ
#
# > Pour σ=0, les neurones sont à leur position initial (placé aléatoirement). Ils ne bougeront pas.
# ![image.png](data:image/png;base64,...)
# Pour σ = 1, les neurones sont éloignés les uns des autres mais ils s’organisent mal, ils ne forment pas de structure droite.
# ![image.png](data:image/png;base64,...)
# Pour σ = 10, les neurones sont proches, comme nous avons dit dans la partie 3, plus le sigma est grand plus les neurones seront proches (l'exponentielle sera plus petite, donc l'inverse aussi et donc les neurones seront plus rapprochés).
# ![image.png](data:image/png;base64,...)
# Pour σ = 100, les neurones sont très proches les uns des autres (tous compresser en un même point). Même explication que pour σ = 10 mais encore plus représentatifs ici.
# ![image.png](data:image/png;base64,...)
#
#
#
#
# - nombre de pas de temps d’apprentissage N
#
#
#
# > Pour N=1, les neurones sont à leur position initiale, N=1 étant trop faible il n'y a pas eu assez de temps d’apprentissage les neurones n’ont donc pas bougé.
# ![image.png](data:image/png;base64,...)
# Pour N=10000, les neurones ont eux le temps d’apprentissage suffisant pour s’organiser au maximum. À partir de N=1000 les postions ne change quasiment plus. Les neurones ont eu assez de pas d'apprentissage pour s'organiser. Il n’est donc a priori pas nécessaire de monter N au-dessus de 1000 dans ce cas précis.
# ![image.png](data:image/png;base64,...)
#
#
# - taille et forme de la carte (vous pouvez tester facilement des formes ’lignes’, ’carrées’ et ’rectangles’)
#
# A partir d'ici nous avons pris comme données de base :
# ETA = 0.05
# sigma = 2
# N = 10000
# Nafficahe = 10
# nsample = 1200
#
# > Nous avons réalisé des ensembles de données pour représenter d’autre forme dans leurs représentations.
# Une ligne qui se forme de façon très « propre ». On aurait pu prédire cela car c’est une forme simple à représenter pour les neurones, la ligne n’est représentée que sur une « dimension » ce qui facilite leurs dispositions.
# Un cercle (que nous avons décidé de concentrer au centre de la grille pour plus de visibilité). La forme n’est pas très bien définie mais on remarque des bords arrondis dans le placement des neurones (tout du moins regroupé sur les bords). On peut peut-être expliquer ça par la quantité de données qui ne permet pas aux neurones de bien se placer sur les bords (voir 3.3 plus haut dans le sujet)
# Un rectangle que ne se forme pas bien. On remarque que les neurones se resserrent sur les côtés mais on retrouve plus une forme de capsule qu’un rectangle car les points sont aussi attirés par le haut du rectangle et donc étire la forme globale.
#
#
# > Ligne :
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
#
# > Cercle :
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
# > Rectangle :
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
# - jeu de données. En particulier créez vos propres jeux de données avec des données non uniformément distribuées pour étudier la répartition des poids des neurones.
#
# > Nous avons créé un jeu de données non uniformes de notre jeu de données du cercle. Ce cercle a une forte densité de données sur les bords et de moins en moins quand on s'approche du centre. On remarque que le cercle est beaucoup mieux formé avec cette disposition que lorsque les données sont uniformes. On peut valider l'hypothèse de la distribution d'entrée de la question 3.3. Les données que reçoivent les neurones sont principalement celle des bords, cela implique que les neurones se "regroupent" sur les bords et donc que ces bords soient plus nets. Il est donc important de se concentrer sur les zones les plus importantes comme les bords que le reste.
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
# > Concernant les autres jeux de donnée nous avons relevé quelques comportements.
# On remarque sur le jeu de données 2 que les neurones sont attirés par les 3 angles haut gauche bas droite bas gauche. On a donc une forme qui ne se rapproche pas du jeu de données mais qui essaye au mieux de ne pas se retrouver dans la zone ou il n’y pas de donnée (haut droite).
#  ![image.png](data:image/png;base64,...)
#  ![image.png](data:image/png;base64,...)
#  > Pour le jeu de donnés 3 on remarque un comportement similaire au rectangle. En effet les neurones essayent de s’allonger au maximum pour atteindre les bord inferieur et supérieur ce qui donnes une forme de capsule.
#  ![image.png](data:image/png;base64,...)
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4.4 Bras robotique
#
# - Une fois la carte apprise, comment faire pour prédire la position qu’aura le bras étant donné une position motrice ? Comment prédire la position motrice étant donné une position spatiale que l’on souhaite atteindre ? Expliquer/justifier le principe et implémentez le.
#
# > Pour prédire la position du bras en fonction d'une commande motrice donnée (θ1, θ2), on trouve le neurone de la carte de Kohonen le plus proche de cette commande, puis on utilise la position de la main (x1, x2) associée à ce neurone pour faire la prédiction. Pour prédire la commande motrice à appliquer pour atteindre une position spatiale donnée, on suit le même processus en inversant les rôles des variables d'entrée et de sortie.
# La position du bras et de la main sont liées, car ils sont physiquement connectés. Si on connait la commande motrice, on peut prédire la position de la main grâce à la géométrie du bras. Et inversement, si on connait la position de la main, on peut déduire la commande motrice nécessaire pour l'amener à cette position grâce à la géométrie du bras.
#
#
# - De quel autre modèle vu en cours se rapproche cette méthode (apprentissage sur le quadruplet pour ensuite en retrouver une sous partie étant donnée l’autre) ? Quels auraient été les avantages et les inconvénients d’utiliser cette autre méthode ?
#
# >  Le perceptron multi-couche est un réseau neuronal qui se compose de plusieurs couches de neurones. Chaque couche est composée de plusieurs neurones qui reçoivent une entrée et produisent une sortie.
# Dans le cas de la prédiction de la position spatiale à partir de la position motrice, les entrées du réseau seraient les valeurs de la position motrice et les sorties seraient les valeurs de la position spatiale correspondante.
# Une fois que le réseau est entraîné, il peut être utilisé pour prédire la position spatiale à partir de la position motrice en entrant les valeurs de position motrice dans le réseau. De même, pour prédire la position motrice.
# Bien que le perceptron multi-couche soit plus lent à entraîner que le perceptron simple, il est capable d'apprendre des relations plus complexes entre les données d'entrée et de sortie, ce qui peut être avantageux dans certains cas. Cela permet aussi de minimiser le taux d'erreurs.
#
# - Si l’objectif était de prédire uniquement la position spatiale à partir de celle motrice, quel autre modèle du cours aurait-on pu utiliser ? Quels auraient été les avantages et les inconvénients ?
#
# > Le Perceptron multi-couches aurait pu être utilisé pour prédire la position spatiale à partir de la position motrice. Les avantages de cette méthode seraient que la prédiction de la position spatiale serait plus précise que celle obtenue avec la méthode de Kohonen, car le Perceptron multi-couches est un modèle plus complexe. Cependant, cette méthode nécessiterait une quantité de données d'apprentissage plus importante et un temps de calcul plus long que la méthode de Kohonen.
# On aurait pu aussi utiliser Perceptron Pour simplement limiter de taux d'erreurs sur des mouvement simple.
#
# - On veut déplacer le bras d’une position motrice (θ1, θ2) à une nouvelle (θ01, θ02). En utilisant la carte apprise, comment prédire la suite des positions spatiales prise par la main ? On demande ici de pouvoir tracer grossièrement la trajectoire, pas forcément d’avoir la fonction exacte de toutes les positions prises. Expliquer/justifier le principe et implémentez le.
#
# > Pour prédire grossièrement la trajectoire de la main à partir de la position motrice de départ et d'arrivée, on peut:
# Diviser le déplacement du bras en plusieurs étapes (choisis unanimement).  Pour chaque étape, on calcule la position motrice correspondante en interpolant linéairement entre la position motrice de départ et d'arrivée. Pour chaque position motrice, on utilise la carte de Kohonen apprise pour trouver la position spatiale correspondante (on cherche le neurone sur la carte qui est le plus proche de la position motrice). On relie ensuite les positions spatiales calculées pour chaque étape pour obtenir une approximation de la trajectoire de la main. Avec cette méthode on obtiendra une approximation de la trajectoire de la main sans avoir besoin d'une modélisation mathématique complexe.

# %% [markdown]
# # 2. Algorithme

# %%
# coding: utf8
#!/usr/bin/env python
# ------------------------------------------------------------------------
# Carte de Kohonen
# Écrit par Mathieu Lefort
#
# Etudiants : VINCENT Yann p1906701 LARIBI Iliesse p1911241
#
# Distribué sous licence BSD.
# ------------------------------------------------------------------------
# Implémentation de l'algorithme des cartes auto-organisatrices de Kohonen
# ------------------------------------------------------------------------
# Pour que les divisions soient toutes réelles (pas de division entière)
from __future__ import division
# Librairie de calcul matriciel
import numpy
# Librairie d'affichage
import matplotlib.pyplot as plt



class Neuron:
  ''' Classe représentant un neurone '''
  
  def __init__(self, w, posx, posy):
    '''
    @summary: Création d'un neurone
    @param w: poids du neurone
    @type w: numpy array
    @param posx: position en x du neurone dans la carte
    @type posx: int
    @param posy: position en y du neurone dans la carte
    @type posy: int
    '''
    # Initialisation des poids
    self.weights = w.flatten()
    # Initialisation de la position
    self.posx = posx
    self.posy = posy
    # Initialisation de la sortie du neurone
    self.y = 0.
  
  def compute(self,x):
    '''
    @summary: Affecte à y la valeur de sortie du neurone (i.e. la distance entre son poids et l'entrée)
    @param x: entrée du neurone
    @type x: numpy array
    '''
    self.y = numpy.linalg.norm(self.weights - x)

  def learn(self,eta,sigma,posxbmu,posybmu,x):
    '''
    @summary: Modifie les poids selon la règle de Kohonen
    @param eta: taux d'apprentissage
    @type eta: float
    @param sigma: largeur du voisinage
    @type sigma: float
    @param posxbmu: position en x du neurone gagnant (i.e. celui dont le poids est le plus proche de l'entrée)
    @type posxbmu: int
    @param posybmu: position en y du neurone gagnant (i.e. celui dont le poids est le plus proche de l'entrée)
    @type posybmu: int
    @param x: entrée du neurone
    @type x: numpy array
    '''

    self.weights[:] = self.weights + eta * numpy.exp(-numpy.linalg.norm(((self.posx - posxbmu)**2+(self.posy - posybmu)**2)) / (2 * sigma**2)) * (x - self.weights)


class SOM:
  ''' Classe implémentant une carte de Kohonen. '''

  def __init__(self, inputsize, gridsize):
    '''
    @summary: Création du réseau
    @param inputsize: taille de l'entrée
    @type inputsize: tuple
    @param gridsize: taille de la carte
    @type gridsize: tuple
    '''
    # Initialisation de la taille de l'entrée
    self.inputsize = inputsize
    # Initialisation de la taille de la carte
    self.gridsize = gridsize
    # Création de la carte
    # Carte de neurones
    self.map = []    
    # Carte des poids
    self.weightsmap = []
    # Carte des activités
    self.activitymap = []
    for posx in range(gridsize[0]):
      mline = []
      wmline = []
      amline = []
      for posy in range(gridsize[1]):
        neuron = Neuron(numpy.random.random(self.inputsize),posx,posy)
        mline.append(neuron)
        wmline.append(neuron.weights)
        amline.append(neuron.y)
      self.map.append(mline)
      self.weightsmap.append(wmline)
      self.activitymap.append(amline)
    self.activitymap = numpy.array(self.activitymap)

  def compute(self,x):
    '''
    @summary: calcule de l'activité des neurones de la carte
    @param x: entrée de la carte (identique pour chaque neurone)
    @type x: numpy array
    '''
    # On demande à chaque neurone de calculer son activité et on met à jour la carte d'activité de la carte
    for posx in range(self.gridsize[0]):
      for posy in range(self.gridsize[1]):
        self.map[posx][posy].compute(x)
        self.activitymap[posx][posy] = self.map[posx][posy].y

  def learn(self,eta,sigma,x):
    '''
    @summary: Modifie les poids de la carte selon la règle de Kohonen
    @param eta: taux d'apprentissage
    @type eta: float
    @param sigma: largeur du voisinage
    @type sigma: float
    @param x: entrée de la carte
    @type x: numpy array
    '''
    # Calcul du neurone vainqueur
    bmux,bmuy = numpy.unravel_index(numpy.argmin(self.activitymap),self.gridsize)
    # Mise à jour des poids de chaque neurone
    for posx in range(self.gridsize[0]):
      for posy in range(self.gridsize[1]):
        self.map[posx][posy].learn(eta,sigma,bmux,bmuy,x)

        
      

  def scatter_plot(self,interactive=False):
    '''
    @summary: Affichage du réseau dans l'espace d'entrée (utilisable dans le cas d'entrée à deux dimensions et d'une carte avec une topologie de grille carrée)
    @param interactive: Indique si l'affichage se fait en mode interactif
    @type interactive: boolean
    '''
    # Création de la figure
    if not interactive:
      plt.figure()
    # Récupération des poids
    w = numpy.array(self.weightsmap)
    # Affichage des poids
    plt.scatter(w[:,:,0].flatten(),w[:,:,1].flatten(),c='k')
    # Affichage de la grille
    for i in range(w.shape[0]):
      plt.plot(w[i,:,0],w[i,:,1],'k',linewidth=1.)
    for i in range(w.shape[1]):
      plt.plot(w[:,i,0],w[:,i,1],'k',linewidth=1.)
    # Modification des limites de l'affichage
    plt.xlim(-1,1)
    plt.ylim(-1,1)
    # Affichage du titre de la figure
    plt.suptitle('Poids dans l\'espace d\'entree')
    # Affichage de la figure
    if not interactive:
      plt.show()

  def scatter_plot_2(self,interactive=False):
    '''
    @summary: Affichage du réseau dans l'espace d'entrée en 2 fois 2d (utilisable dans le cas d'entrée à quatre dimensions et d'une carte avec une topologie de grille carrée)
    @param interactive: Indique si l'affichage se fait en mode interactif
    @type interactive: boolean
    '''
    # Création de la figure
    if not interactive:
      plt.figure()
    # Affichage des 2 premières dimensions dans le plan
    plt.subplot(1,2,1)
    # Récupération des poids
    w = numpy.array(self.weightsmap)
    # Affichage des poids
    plt.scatter(w[:,:,0].flatten(),w[:,:,1].flatten(),c='k')
    # Affichage de la grille
    for i in range(w.shape[0]):
      plt.plot(w[i,:,0],w[i,:,1],'k',linewidth=1.)
    for i in range(w.shape[1]):
      plt.plot(w[:,i,0],w[:,i,1],'k',linewidth=1.)
    # Affichage des 2 dernières dimensions dans le plan
    plt.subplot(1,2,2)
    # Récupération des poids
    w = numpy.array(self.weightsmap)
    # Affichage des poids
    plt.scatter(w[:,:,2].flatten(),w[:,:,3].flatten(),c='k')
    # Affichage de la grille
    for i in range(w.shape[0]):
      plt.plot(w[i,:,2],w[i,:,3],'k',linewidth=1.)
    for i in range(w.shape[1]):
      plt.plot(w[:,i,2],w[:,i,3],'k',linewidth=1.)
    # Affichage du titre de la figure
    plt.suptitle('Poids dans l\'espace d\'entree')
    # Affichage de la figure
    if not interactive:
      plt.show()

  def plot(self):
    '''
    @summary: Affichage des poids du réseau (matrice des poids)
    '''
    # Récupération des poids
    w = numpy.array(self.weightsmap)
    # Création de la figure
    f,a = plt.subplots(w.shape[0],w.shape[1])    
    # Affichage des poids dans un sous graphique (suivant sa position de la SOM)
    for i in range(w.shape[0]):
      for j in range(w.shape[1]):
        plt.subplot(w.shape[0],w.shape[1],i*w.shape[1]+j+1)
        im = plt.imshow(w[i,j].reshape(self.inputsize),interpolation='nearest',vmin=numpy.min(w),vmax=numpy.max(w),cmap='binary')
        plt.xticks([])
        plt.yticks([])
    # Affichage de l'échelle
    f.subplots_adjust(right=0.8)
    cbar_ax = f.add_axes([0.85, 0.15, 0.05, 0.7])
    f.colorbar(im, cax=cbar_ax)
    # Affichage du titre de la figure
    plt.suptitle('Poids dans l\'espace de la carte')
    # Affichage de la figure
    plt.show()

  def MSE(self,X):
    '''
    @summary: Calcul de l'erreur de quantification vectorielle moyenne du réseau sur le jeu de données
    @param X: le jeu de données
    @type X: numpy array
    '''
    # On récupère le nombre d'exemples
    nsamples = X.shape[0]
    # Somme des erreurs quadratiques
    s = 0
    # Pour tous les exemples du jeu de test
    for x in X:
      # On calcule la distance à chaque poids de neurone
      self.compute(x.flatten())
      # On rajoute la distance minimale au carré à la somme
      s += numpy.min(self.activitymap)**2
    # On renvoie l'erreur de quantification vectorielle moyenne
    return s/nsamples

# -----------------------------------------------------------------------------
if __name__ == '__main__':
  # Création d'un réseau avec une entrée (2,1) et une carte (10,10)
  # mettre à jour la taille des données d'entrée pour les données robotiques
  network = SOM((2,1),(10,10))
  # PARAMÈTRES DU RÉSEAU
  # Taux d'apprentissage
  ETA = 0.05
  # Largeur du voisinage
  SIGMA = 2
  # Nombre de pas de temps d'apprentissage
  N = 10000
  # Affichage interactif de l'évolution du réseau 
  # mettre à faux pour que les simulations aillent plus vite
  VERBOSE = True
  # Nombre de pas de temps avant rafraissichement de l'affichage
  NAFFICHAGE = 100
  # DONNÉES D'APPRENTISSAGE
  # Nombre de données à générer pour les ensembles 1, 2 et 3
  # décommenter les données souhaitées
  nsamples = 1200
  # Ensemble de données 1
 # samples = numpy.random.random((nsamples,2,1))*2-1
  # Ensemble de données 2
  #samples1 = -numpy.random.random((nsamples//3,2,1))
  #samples2 = numpy.random.random((nsamples//3,2,1))
  #samples2[:,0,:] -= 1
  #samples3 = numpy.random.random((nsamples//3,2,1))
  #samples3[:,1,:] -= 1
  #samples = numpy.concatenate((samples1,samples2,samples3))
  # Ensemble de données 3
  #samples1 = numpy.random.random((nsamples//2,2,1))
  #samples1[:,0,:] -= 1
  #samples2 = numpy.random.random((nsamples//2,2,1))
  #samples2[:,1,:] -= 1
  #samples = numpy.concatenate((samples1,samples2))
  # Ensemble de données robotiques
  samples = numpy.random.random((nsamples,4,1))
  samples[:,0:2,:] *= numpy.pi
  l1 = 0.7
  l2 = 0.3
  samples[:,2,:] = l1*numpy.cos(samples[:,0,:])+l2*numpy.cos(samples[:,0,:]+samples[:,1,:])
  samples[:,3,:] = l1*numpy.sin(samples[:,0,:])+l2*numpy.sin(samples[:,0,:]+samples[:,1,:])
  # Affichage des données (pour les ensembles 1, 2 et 3)
  '''
  plt.figure()
  plt.scatter(samples[:,0,0], samples[:,1,0])
  plt.xlim(-1,1)
  plt.ylim(-1,1)
  plt.suptitle('Donnees apprentissage')
  plt.show()
  '''
  # Affichage des données (pour l'ensemble robotique)
  plt.figure()
  plt.subplot(1,2,1)
  plt.scatter(samples[:,0,0].flatten(),samples[:,1,0].flatten(),c='k')
  plt.subplot(1,2,2)
  plt.scatter(samples[:,2,0].flatten(),samples[:,3,0].flatten(),c='k')
  plt.suptitle('Donnees apprentissage')
  plt.show()

  # NOUVEAU JEUX DE DONNÉES
  '''
  # CERCLE
  # Générer des coordonnées aléatoires
  theta = numpy.random.rand(nsamples) * 2 * numpy.pi
  r = numpy.sqrt(numpy.random.rand(nsamples)) * 0.5

  # Conversion des coordonnées 
  x = r * numpy.cos(theta)
  y = r * numpy.sin(theta)

  # Concaténarion
  samples = numpy.column_stack((x, y))

  # Affichage
  plt.figure()
  plt.scatter(x, y)
  plt.xlim(-1, 1)
  plt.ylim(-1, 1)
  plt.suptitle('Donnees apprentissage')
  plt.show()
  '''
  
  '''
  # LIGNE
  # Générer des coordonnées aléatoires
  x = numpy.linspace(-1, 1, nsamples)
  y = numpy.zeros(nsamples)

  samples = numpy.column_stack((x, y))

  # Affichage
  plt.figure()
  plt.scatter(x, y)
  plt.xlim(-1, 1)
  plt.ylim(-1, 1)
  plt.suptitle('Donnees apprentissage')
  plt.show()
  '''
  '''
  # RECTANGLE
  # Générer des coordonnées aléatoires
  samples = numpy.random.random((nsamples,2))*2-1

  # Modifier les coordonnées x pour créer un rectangle allongé vers le haut
  samples[:,0] *= 0.4

  # Affichage
  plt.figure()
  plt.scatter(samples[:,0], samples[:,1])
  plt.xlim(-1, 1)
  plt.ylim(-1, 1)
  plt.suptitle('Donnees apprentissage')
  plt.show()
  '''
  
  '''
  # CERCLE non uniforme, moins de données au centre
  # Générer des coordonnées aléatoires
  theta = numpy.random.rand(nsamples) * 2 * numpy.pi
  r = numpy.sqrt(numpy.random.rand(nsamples))*0.5 + 0.5

  # Conversion des coordonnées
  x = r * numpy.cos(theta)
  y = r * numpy.sin(theta)

  # Concaténarion
  samples = numpy.column_stack((x, y))

  # Afficher les points générés
  plt.figure()
  plt.scatter(x, y)
  plt.xlim(-1, 1)
  plt.ylim(-1, 1)
  plt.suptitle('Donnees apprentissage')
  plt.show()
  '''


    
  # SIMULATION
  # Affichage des poids du réseau
  network.plot()
  # Initialisation de l'affichage interactif
  if VERBOSE:
    # Création d'une figure
    plt.figure()
    # Mode interactif
    plt.ion()
    # Affichage de la figure
    plt.show()
  # Boucle d'apprentissage
  for i in range(N+1):
    # Choix d'un exemple aléatoire pour l'entrée courante
    index = numpy.random.randint(nsamples)
    x = samples[index].flatten()
    # Calcul de l'activité du réseau
    network.compute(x)
    # Modification des poids du réseau
    network.learn(ETA,SIGMA,x)
    # Mise à jour de l'affichage
    if VERBOSE and i%NAFFICHAGE==0:
      # Effacement du contenu de la figure
      plt.clf()
      # Remplissage de la figure
      network.scatter_plot(True)
      # Affichage du contenu de la figure
      plt.pause(0.00001)
      plt.draw()
  # Fin de l'affichage interactif
  if VERBOSE:
    # Désactivation du mode interactif
    plt.ioff()
  # Affichage des poids du réseau
  network.plot()
  # Affichage de l'erreur de quantification vectorielle moyenne après apprentissage
  print("erreur de quantification vectorielle moyenne ",network.MSE(samples))

# %% [markdown]
# Concernant le code en plus des implementations nous avons rajouté nos propres modèles de données comme indique dans la partie 4.3. La Ligne, le cercle, le rectangle et le cercle non uniforme.
